# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
hockey_file = Path("Resources/players.csv")

player_file = Path("Resources/player_summary.xlsx")
goalie_file = Path("Resources/goalie_summary.xlsx")
defence_file = Path("Resources/defensemen_summary.xlsx")




# Displaying dataframe for all hockey players 

hockey_summary_df = pd.read_csv(hockey_file, encoding="utf-8")
hockey_summary_df.head(10)
# Out:
#    player_id          name nationality pos           birth_date height_in  \
# 0    8465009      Z. Chara         SVK   D  1977-03-18 00:00:00     6' 9"
# 1    8466138   J. Thornton         CAN   C  1979-07-02 01:00:00     6' 4"
# 2    8466139    P. Marleau         CAN   C  1979-09-15 01:00:00     6' 2"
# 3    8468493    R. Hainsey         USA   D  1981-03-24 00:00:00     6' 3"
# 4    8468508   J. Williams         CAN  RW  1981-10-04 01:00:00     6' 1"
# 5    8468674  D. Engelland         CAN   D  1982-04-03 01:00:00     6' 2"
# 6    8469454  I. Kovalchuk         RUS  RW  1983-04-15 01:00:00     6' 3"
# 7    8469455     J. Spezza         CAN   C  1983-06-13 01:00:00     6' 3"
# 8    8469459      M. Koivu         FIN   C  1983-03-12 00:00:00     6' 3"
# 9    8469465    D. Hamhuis         CAN   D  1982-12-13 00:00:00     6' 1"
#
#    height_cm  weight_lb   weight_kg  team_id  team_id2  team_id3 birth_city  \
# 0     205.74      250.0  113.398000        6         0         0    Trencin
# 1     193.04      220.0   99.790240       28         0         0     London
# 2     187.96      215.0   97.522280       28         5         0    Aneroid
# 3     190.50      210.0   95.254320        9         0         0     Bolton
# 4     185.42      188.0   85.275296       12         0         0    Cobourg
# 5     187.96      214.0   97.068688       54         0         0   Edmonton
# 6     190.50      230.0  104.326160       26         8        15       Tver
# 7     190.50      214.0   97.068688       10         0         0    Toronto
# 8     190.50      215.0   97.522280       30         0         0      Turku
# 9     185.42      204.0   92.532768       18         0         0   Smithers
#
#   birth_state_prov hand team
# 0              NaN    L  BOS
# 1               ON    L  SJS
# 2               SK    L  SJS
# 3               CT    L  OTT
# 4               ON    R  CAR
# 5               AB    R  VGK
# 6              NaN    R  LAK
# 7               ON    R  TOR
# 8              NaN    L  MIN
# 9               BC    L  NSH

# %%
# Data columns info

hockey_summary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   player_id         757 non-null    int64
#  1   name              757 non-null    object
#  2   nationality       757 non-null    object
#  3   pos               757 non-null    object
#  4   birth_date        757 non-null    object
#  5   height_in         757 non-null    object
#  6   height_cm         757 non-null    float64
#  7   weight_lb         757 non-null    float64
#  8   weight_kg         757 non-null    float64
#  9   team_id           757 non-null    int64
#  10  team_id2          757 non-null    int64
#  11  team_id3          757 non-null    int64
#  12  birth_city        757 non-null    object
#  13  birth_state_prov  532 non-null    object
#  14  hand              757 non-null    object
#  15  team              757 non-null    object
# dtypes: float64(3), int64(4), object(9)
# memory usage: 94.8+ KB

# %%
# Determining the nationalities of hockey player as per the database.

nationality = hockey_summary_df["nationality"].unique().tolist()

nationality
# Out:
# ['SVK',
#  'CAN',
#  'USA',
#  'RUS',
#  'FIN',
#  'DNK',
#  'SWE',
#  'CZE',
#  'SVN',
#  'AUT',
#  'CHE',
#  'FRA',
#  'NOR',
#  'DEU',
#  'LVA',
#  'GBR',
#  'NLD',
#  'UKR']

# %%
# Birthcity of the hockey players

birthcity = hockey_summary_df["birth_city"].unique().tolist()

birthcity
# Out:
# ['Trencin',
#  'London',
#  'Aneroid',
#  'Bolton',
#  'Cobourg',
#  'Edmonton',
#  'Tver',
#  'Toronto',
#  'Turku',
#  'Smithers',
#  'Vantaa',
#  'Herning',
#  'Winnipeg',
#  'Karlskrona',
#  'Thunder Bay',
#  'Madison',
#  'Shaunavon',
#  'Ithaca',
#  'Richmond',
#  'Minneapolis',
#  'Regina',
#  'Barrie',
#  'Hingham',
#  'Peterborough',
#  'Gothenburg',
#  'Ancienne-Lorette',
#  'Sicamous',
#  'Belleville',
#  'Anchorage',
#  'Plover',
#  'Moscow',
#  'Magnitogorsk',
#  'Maple Ridge',
#  'Plymouth',
#  'Nizhny Tagil',
#  'Calgary',
#  'Meadow Lake',
#  'Malmö',
#  'Grand Rapids',
#  'Sternberk',
#  'Bojnice',
#  'Ostersund',
#  'Ostrava',
#  'Vancouver',
#  'Quebec City',
#  'Cole Harbour',
#  'Cherry Hill',
#  'Indianapolis',
#  'Jesenice',
#  'Everett',
#  'Virginia',
#  'Whitby',
#  'Montreal',
#  'Muskegon',
#  'Caroline',
#  'Boston',
#  'Trebic',
#  'Eksjo',
#  'St. Andrews',
#  'Oxford',
#  'Tibro',
#  'Sollentuna',
#  'Trenton',
#  'Halifax',
#  'Buffalo',
#  'Bloomington',
#  'St. Paul',
#  'Salt Lake City',
#  'Narva',
#  'Welland',
#  'Ann Arbor',
#  'Hearst',
#  'Hull',
#  'Villach',
#  'Gävle',
#  'Kladno',
#  'Yaroslavl',
#  'Drummondville',
#  'Burnaby',
#  'Victoria',
#  'Hartford',
#  'New Rochelle',
#  'St. Louis',
#  'Middletown',
#  'Ottawa',
#  'Guelph',
#  'Consort',
#  'New Westminster',
#  'Mimico',
#  'Huntington',
#  'Red Deer',
#  'Sherbrooke',
#  'Orebro',
#  'Morges',
#  'Chelyabinsk',
#  'Vasteras',
#  'New Canaan',
#  'Woodstock',
#  'Rochester Hills',
#  'Sodertalje',
#  'Rodovre',
#  'Scarborough',
#  'St. Albert',
#  'Dorval',
#  'Maple Creek',
#  'Markham',
#  'King City',
#  'Massena',
#  'Saskatoon',
#  'Brondby',
#  'Bowmanville',
#  'Houston',
#  'Landsbro',
#  'Ozieri',
#  'Minnetonka',
#  'Stouffville',
#  'Natick',
#  'Mississauga',
#  'Bern',
#  'Kelowna',
#  'Roseau',
#  'St. Malo',
#  'Hastings',
#  'Brantford',
#  'Chatham',
#  'Halmstad',
#  'Abbotsford',
#  'Brandon',
#  'Sterling Heights',
#  'Windsor',
#  'Riverside',
#  'Holland',
#  'Roubaix',
#  'Spokane',
#  'Kitchener',
#  'Landskrona',
#  'Smithtown',
#  'Clinton',
#  'Ayr',
#  'Ornskoldsvik',
#  'Haliburton',
#  'Hamilton',
#  'Carp',
#  'Lipetsk',
#  'Eden Prairie',
#  'Boxford',
#  'Winnetka',
#  'Davidson',
#  'Ilava',
#  'Novokuznetsk',
#  'Biddeford',
#  'Martin',
#  'Borlange',
#  'Jyväskylä',
#  'St. Hyacinthe',
#  'LaSalle',
#  'Ville Degelis',
#  'Rimouski',
#  'Pori',
#  'Edina',
#  'Huntsville',
#  'Prince George',
#  'Kleinburg',
#  'Prague',
#  'Oslo',
#  'Kosice',
#  'Tonka Bay',
#  'Newport Beach',
#  'Lau',
#  'St. Thomas',
#  'North Vancouver',
#  'E. Weymouth',
#  'Stockholm',
#  'Oklahoma City',
#  'South St.Paul',
#  'Warroad',
#  'Duluth',
#  'Dorchester',
#  'Wilcox',
#  'St. Catharines',
#  'Walpole',
#  'Campbell River',
#  'Brampton',
#  'Sherwood Park',
#  'Burnsville',
#  'Oulu',
#  'Chur',
#  'Ile Bizard',
#  'Pontiac',
#  'Raahe',
#  'Landshut',
#  'Nassjo',
#  'Island Park',
#  'Taber',
#  'Carmel',
#  'Swan River',
#  'Coquitlam',
#  'Braintree',
#  'Lawrence',
#  'Petawawa',
#  'Wheaton',
#  'Frydek-Mistek',
#  'Hinsdale',
#  'Hopkins',
#  'Salem',
#  'Dublin',
#  'Pittsburgh',
#  'Orland Park',
#  'Plano',
#  'Glace Bay',
#  'Pickering',
#  'Denver',
#  'Innisfil',
#  'Chicago',
#  'Anaheim',
#  'Leksand',
#  'Orangeville',
#  'Long Beach',
#  'Bayonne',
#  'Marsta',
#  'Kingston',
#  'Maykop',
#  'Saint-Jerome',
#  'Skellefteå',
#  'Huddinge',
#  'Phoenix',
#  'Karlstad',
#  'East Palestine',
#  'Strathroy',
#  'Victoriaville',
#  'Zhukovskiy',
#  'Sundbyberg',
#  'Sault Ste. Marie',
#  'Cap-Rouge',
#  'Livonia',
#  'Saint-Narcisse',
#  'Milwaukee',
#  'Helsingborg',
#  'Lakeville',
#  'Oakville',
#  'Pointe-Claire',
#  'Riga',
#  'Praha',
#  'Helsinki',
#  'Rochester',
#  'Winchester',
#  'Ostervala',
#  'Vitkov',
#  'Charlestown',
#  'Boden',
#  'Pembroke Pines',
#  'Bloomfield Hills',
#  'Ajax',
#  'Surrey',
#  'Keswick',
#  'Syracuse',
#  'Melville',
#  'Pelhrimov',
#  'Eau Claire',
#  'Fergus',
#  'Alma',
#  'Woodbridge',
#  'Gaspe',
#  'Nynashamn',
#  'Burlington',
#  'Cambridge',
#  'Brockville',
#  'Rumson',
#  'Sauble Beach',
#  'Orleans',
#  'Merrimack',
#  'Detroit',
#  'St. Cloud',
#  'Grand Prairie',
#  'San Diego',
#  'Plzen',
#  'St. Clair',
#  'Sun Prairie',
#  'Dubuque',
#  'Long Branch',
#  'Viking',
#  'Cherepovets',
#  'Omaha',
#  'Yarmouth',
#  'Klagenfurt',
#  'Langley',
#  'Georgetown',
#  'Hilton Head Isl.',
#  'New Haven',
#  'Arvika',
#  'Northbrook',
#  'Uppsala',
#  'Delta',
#  'Piikkio',
#  'Sudbury',
#  'Tarrytown',
#  'Tampere',
#  'Ste-Agathe',
#  'Arlington',
#  'Dauphin',
#  'Salmon Arm',
#  'Winterthur',
#  'Longueuil',
#  'Laval',
#  'Charlottetown',
#  'Battleford',
#  'Oviedo',
#  'Dearborn Heights',
#  'Kennebunkport',
#  'Lycksele',
#  'Le Blanc-Mesnil',
#  'Pardubice',
#  'West Vancouver',
#  'Cologne',
#  'Holland Landing',
#  'Richmond Hill',
#  'Carlyle',
#  'Aalborg',
#  'St. Gallen',
#  'Guildford',
#  'Waterford',
#  'Massapequa',
#  'Elkhorn',
#  'Sewell',
#  'Kuopio',
#  'Stratford',
#  'Havirov',
#  'Kramfors',
#  'Yorkton',
#  'Orsk',
#  'Slave Lake',
#  'Palos',
#  'Umea',
#  'Skara',
#  'Hollidaysburg',
#  "St. John's",
#  'Albany',
#  'Mequon',
#  'Brooklyn',
#  'Montmagny',
#  'Ljungby',
#  'Kadan',
#  'Kamloops',
#  'Cranbrook',
#  'East Longmeadow',
#  'Fairport',
#  'Shelby Twp.',
#  'Zurich',
#  'Brno',
#  'North Chelmsford',
#  'Newmarket',
#  'Canton',
#  'Herisau',
#  'Nousiainen',
#  'Cleveland',
#  'Rauma',
#  'Colorado Springs',
#  'Columbus',
#  'Grosse Pointe',
#  'Amos',
#  'Sorel-Tracy',
#  'Amsterdam',
#  "Val D'or",
#  'Sainte-Marie',
#  'Mt. Brydges',
#  'Togliatti',
#  'North Easton',
#  'Etobicoke',
#  'Korkino',
#  'Volketswil',
#  'Johnston',
#  'Olten',
#  'Ufa',
#  'Scituate',
#  'Kirovograd',
#  'Latvia',
#  'Green Bay',
#  'Haapavesi',
#  'Moncton',
#  'Scottsdale',
#  'Chesterfield',
#  'San Ramon',
#  'Jericho',
#  'Pointe-aux-Trembles',
#  'Smrcek',
#  'Farmington Hills',
#  'Boca Raton',
#  'Golden',
#  'Ardrossan',
#  'Raleigh',
#  'Parkland',
#  'Thornhill',
#  'Beaumont',
#  'Roberval',
#  'Ste-Agathe-Des-Monts',
#  'Nizhnekamsk',
#  'Hradec Králové',
#  'Holte',
#  'Hodonin',
#  'Nokia',
#  'Frederikshavn',
#  'Bonney Lake',
#  'Moose Jaw',
#  'Biloxi',
#  'Thousand Oaks',
#  'Las Vegas',
#  'Wyandotte',
#  'Staten Island',
#  'Fridley',
#  'Brig',
#  'Falun',
#  'Sundsvall',
#  'Aurora',
#  'Espoo',
#  'Nove Mesto na Morave',
#  'Kristianstad',
#  'Smogen',
#  "St. Martin D'heres",
#  'Kromeriz',
#  'Eden',
#  'Chomutov',
#  'Hermantown',
#  'Ljunby',
#  'Vaxjo',
#  'Mlada Boleslav',
#  'Písek',
#  'Siilinjarvi',
#  'Nykoping',
#  'Tyreso',
#  'BELLMAWR',
#  'Caslav',
#  'Quincy',
#  'Bratislava',
#  'Orlando',
#  'Gallivare',
#  'Barnaul',
#  'Lidkoping',
#  'Summerside',
#  'Esko',
#  'Kusmark',
#  'Joensuu',
#  'Plana',
#  'Tingsryd',
#  'Missouri City',
#  'Augsburg',
#  'Lindstrom',
#  'Fort Saskatchewan',
#  'Omsk',
#  'Malmo',
#  'Bonfol']

# %%
# Displaying players by first letter of first name and then their last name. 

def fix_name(x):
    names = x.split(" ")
    first_initial = names[0][0]
    return f"{first_initial}. {names[1]}"

# %%
# Player summary of the top 40 players by points currently in the NHL. 

player_summary_df = pd.read_excel(player_file, engine="openpyxl")
player_summary_df["name"]= player_summary_df["Player"].map(fix_name)
player_summary_df.rename(columns={"Team": "team"}, inplace=True)

player_summary_df.head()
# Out:
#              Player    Season team S/C Pos  GP   G   A   P  +/-  ...  PPP  \
# 0   Nikita Kucherov  20232024  TBL   L   R  40  28  39  67   -3  ...   30
# 1  Nathan MacKinnon  20232024  COL   R   C  40  22  43  65    9  ...   26
# 2    David Pastrnak  20232024  BOS   R   R  38  24  31  55   11  ...   22
# 3    Artemi Panarin  20232024  NYR   R   L  38  25  30  55    2  ...   23
# 4    Connor McDavid  20232024  EDM   L   C  34  14  40  54   10  ...   20
#
#    SHG  SHP  OTG  GWG    S    S%  TOI/GP  FOW%          name
# 0    0    0    1    5  178  15.7   21:46    50   N. Kucherov
# 1    0    0    2    4  179  12.3   22:49  49.1  N. MacKinnon
# 2    0    0    0    4  189  12.7   19:46  28.6   D. Pastrnak
# 3    0    0    0    2  159  15.7   19:57  14.3    A. Panarin
# 4    0    0    0    0  104  13.5   21:19  50.4    C. McDavid
#
# [5 rows x 25 columns]

# %%
# Merging the data from the hockey player database (previous) and the top 40 players by points database. 

player_merge_df = pd.merge(player_summary_df, hockey_summary_df, on=["name", "team"])

player_merge_df.head(15)
# Out:
#               Player    Season team S/C Pos  GP   G   A   P  +/-  ...  \
# 0    Nikita Kucherov  20232024  TBL   L   R  40  28  39  67   -3  ...
# 1   Nathan MacKinnon  20232024  COL   R   C  40  22  43  65    9  ...
# 2     David Pastrnak  20232024  BOS   R   R  38  24  31  55   11  ...
# 3     Artemi Panarin  20232024  NYR   R   L  38  25  30  55    2  ...
# 4     Connor McDavid  20232024  EDM   L   C  34  14  40  54   10  ...
# 5   William Nylander  20232024  TOR   R   R  37  21  33  54    5  ...
# 6        J.T. Miller  20232024  VAN   L   C  39  18  35  53   18  ...
# 7     Mikko Rantanen  20232024  COL   L   R  40  20  30  50    1  ...
# 8       Quinn Hughes  20232024  VAN   L   D  39  10  39  49   26  ...
# 9   Elias Pettersson  20232024  VAN   L   C  39  17  31  48   13  ...
# 10        Cale Makar  20232024  COL   R   D  35   9  38  47    8  ...
# 11     Sebastian Aho  20232024  CAR   L   C  37  15  31  46    9  ...
# 12       Jack Hughes  20232024  NJD   L   C  32  15  30  45   -5  ...
# 13   Auston Matthews  20232024  TOR   L   C  36  30  15  45    7  ...
# 14    Filip Forsberg  20232024  NSH   R   L  40  21  24  45    7  ...
#
#     height_in  height_cm  weight_lb  weight_kg  team_id  team_id2  team_id3  \
# 0      5' 11"     180.34      178.0  80.739376       14         0         0
# 1       6' 0"     182.88      205.0  92.986360       21         0         0
# 2       6' 0"     182.88      181.0  82.100152        6         0         0
# 3      5' 11"     180.34      168.0  76.203456        3         0         0
# 4       6' 1"     185.42      192.0  87.089664       22         0         0
# 5       6' 0"     182.88      191.0  86.636072       10         0         0
# 6       6' 1"     185.42      218.0  98.883056       23         0         0
# 7       6' 4"     193.04      211.0  95.707912       21         0         0
# 8      5' 10"     177.80      170.0  77.110640       23         0         0
# 9       6' 2"     187.96      176.0  79.832192       23         0         0
# 10     5' 11"     180.34      187.0  84.821704       21         0         0
# 11     5' 11"     180.34      172.0  78.017824       12         0         0
# 12     5' 11"     180.34      170.0  77.110640        1         0         0
# 13      6' 3"     190.50      216.0  97.975872       10         0         0
# 14      6' 1"     185.42      205.0  92.986360       18         0         0
#
#         birth_city  birth_state_prov  hand
# 0           Maykop               NaN     L
# 1          Halifax                NS     R
# 2          Havirov               NaN     R
# 3          Korkino               NaN     R
# 4    Richmond Hill                ON     L
# 5          Calgary                AB     R
# 6   East Palestine                OH     L
# 7       Nousiainen               NaN     L
# 8          Orlando                FL     L
# 9        Sundsvall               NaN     L
# 10         Calgary                AB     R
# 11           Rauma               NaN     L
# 12         Orlando                FL     L
# 13       San Ramon                CA     L
# 14       Ostervala               NaN     R
#
# [15 rows x 39 columns]

# %%
# Column info

player_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 0 to 38
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Player            39 non-null     object
#  1   Season            39 non-null     int64
#  2   team              39 non-null     object
#  3   S/C               39 non-null     object
#  4   Pos               39 non-null     object
#  5   GP                39 non-null     int64
#  6   G                 39 non-null     int64
#  7   A                 39 non-null     int64
#  8   P                 39 non-null     int64
#  9   +/-               39 non-null     int64
#  10  PIM               39 non-null     int64
#  11  P/GP              39 non-null     float64
#  12  EVG               39 non-null     int64
#  13  EVP               39 non-null     int64
#  14  PPG               39 non-null     int64
#  15  PPP               39 non-null     int64
#  16  SHG               39 non-null     int64
#  17  SHP               39 non-null     int64
#  18  OTG               39 non-null     int64
#  19  GWG               39 non-null     int64
#  20  S                 39 non-null     int64
#  21  S%                39 non-null     float64
#  22  TOI/GP            39 non-null     object
#  23  FOW%              39 non-null     object
#  24  name              39 non-null     object
#  25  player_id         39 non-null     int64
#  26  nationality       39 non-null     object
#  27  pos               39 non-null     object
#  28  birth_date        39 non-null     object
#  29  height_in         39 non-null     object
#  30  height_cm         39 non-null     float64
#  31  weight_lb         39 non-null     float64
#  32  weight_kg         39 non-null     float64
#  33  team_id           39 non-null     int64
#  34  team_id2          39 non-null     int64
#  35  team_id3          39 non-null     int64
#  36  birth_city        39 non-null     object
#  37  birth_state_prov  24 non-null     object
#  38  hand              39 non-null     object
# dtypes: float64(5), int64(20), object(14)
# memory usage: 12.2+ KB

# %%
# Merged dataset displaying points by nationality. 

nationality_points = player_merge_df.groupby("nationality")["P"].sum()

nationality_points
# Out:
# nationality
# CAN    633
# CZE     55
# DEU     42
# FIN    139
# RUS    162
# SVN     36
# SWE    304
# USA    346
# Name: P, dtype: int64

# %%
# Bar Chart for points by Nationality for top 40 players by points in NHL 

points_chart = nationality_points.plot(kind="bar", color="blue", figsize=(6,6))
plt.title("POINTS BY NATIONALITY")
points_chart.set_xlabel("NATIONALITY")
points_chart.set_ylabel("POINTS")

plt.grid()
plt.show()
plt.tight_layout()

# %%
# Displaying the number of points based on players heights. 

player_height = player_merge_df.groupby("height_in")["G","A","P"].sum()

player_height
# Out:
# /var/folders/9_/7zypvl995tn69w8g5z3_xs8m0000gn/T/ipykernel_18881/607101214.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   player_height = player_merge_df.groupby("height_in")["G","A","P"].sum()
#              G    A    P
# height_in
# 5' 10"      64  107  171
# 5' 11"     147  232  379
# 5' 9"       15   20   35
# 6' 0"      120  212  332
# 6' 1"       93  138  231
# 6' 2"       64  100  164
# 6' 3"       89  110  199
# 6' 4"       58  109  167
# 6' 6"        6   33   39

# %%
# Plot the points by Player's Height

height_chart = player_height.plot(kind = "bar", color="lightskyblue", figsize=(6,6))
plt.title("POINTS BY PLAYER HEIGHT")


plt.grid()
plt.show()
plt.tight_layout()

# %%
# Bar Chart for sorted points per height from highest to lowest 

sorted_height_stats = player_height.plot(kind ="bar", color="green", figsize=(7,7))

plt.title("STATS per HEIGHT sorted")

plt.grid()
plt.show()
plt.tight_layout()

# %%
# Displaying player's point total by weight

player_weight = player_merge_df.groupby("weight_lb")["P"].sum()

player_weight.head(10)
# Out:
# weight_lb
# 166.0     42
# 168.0     55
# 170.0     94
# 172.0     46
# 175.0    120
# 176.0     48
# 178.0     67
# 180.0     43
# 181.0     90
# 184.0     38
# Name: P, dtype: int64

# %%
#Plotting graph for points by player weight

weight_chart = player_weight.plot(kind="bar", color="violet", figsize=(8,8))


plt.title("POINTS BY WEIGHT")

plt.grid()
plt.show()
plt.tight_layout()

# %%
# Sort data by player's points by weight from highest to lowest.

player_weight_sorted = player_weight.sort_values("weight_lb", ascending=False)

player_weight_sorted.head(15)
# Out:
# /var/folders/9_/7zypvl995tn69w8g5z3_xs8m0000gn/T/ipykernel_18881/955777123.py:3: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   player_weight_sorted = player_weight.sort_values("weight_lb", ascending=False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'weight_lb'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Sort data by player's points by weight from highest to lowest.
# ----> 3 player_weight_sorted = player_weight.sort_values("weight_lb", ascending=False)
#       5 player_weight_sorted.head(15)
#
# File ~/opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/series.py:3744, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3742 inplace = validate_bool_kwarg(inplace, "inplace")
#    3743 # Validate the axis parameter
# -> 3744 self._get_axis_number(axis)
#    3746 # GH 5856/5853
#    3747 if inplace and self._is_cached:
#
# File ~/opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:556, in NDFrame._get_axis_number(cls, axis)
#     554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
# --> 556     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named weight_lb for object type Series

# %%
#Plot the sorted weight stats

sorted_weight_stats = player_weight_sorted.plot(kind="bar", color="indigo", figsize=(8,8))

plt.title("STATS PER WEIGHT sorted")

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 #Plot the sorted weight stats
# ----> 3 sorted_weight_stats = player_weight_sorted.plot(kind="bar", color="indigo", figsize=(8,8))
#       5 plt.title("STATS PER WEIGHT sorted")
#       7 plt.grid()
#
# AttributeError: 'bool' object has no attribute 'plot'

# %%
player_position = player_merge_df.groupby("Pos")["G", "A", "P"].sum()

player_position

# %%
player_weight_df = player_merge_df.groupby("weight_lb")["P"].sum()

player_weight_df.head(15)

# %%
player_weight_sorted = player_weight_df.sort_values("P", ascending=False)

player_weight_sorted.head(10)

# %%
goalie_summary_df = goalie_summary_df.sort_values("Sv%", ascending=False)

goalie_summary_df.head(15)

# %%
goalie_summary_df["T"] = pd.to_numeric(goalie_summary_df["T"], errors="coerce")
goalie_summary_df["TOI"] = pd.to_numeric(goalie_summary_df["TOI"], errors="coerce")

# %%
goalie_summary_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 goalie_summary_df.info()
#
# NameError: name 'goalie_summary_df' is not defined

# %%
#Plot the Goalie stats by Wins 


goalie_wins = goalie_summary_df.plot["W"](kind="bar", figsize=(8,10), color="gold", rotation="vertical")


plt.title("GOALIE WINS")
plt.xlabel("Players")
plt.ylabel("Goalie Wins")


plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 #Plot the Goalie stats by Wins
# ----> 4 goalie_wins = goalie_summary_df.plot["W"](kind="bar", figsize=(8,10), color="gold", rotation="vertical")
#       7 plt.title("GOALIE WINS")
#       8 plt.xlabel("Players")
#
# NameError: name 'goalie_summary_df' is not defined

# %%
goalie_summary_df = goalie_summary_df.sort_values("GAA", ascending=True)

goalie_summary_df.head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 goalie_summary_df = goalie_summary_df.sort_values("GAA", ascending=True)
#       3 goalie_summary_df.head(15)
#
# NameError: name 'goalie_summary_df' is not defined

# %%
goalie_summary_df = goalie_summary_df.sort_values("Svs", ascending=False)

goalie_summary_df.head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 goalie_summary_df = goalie_summary_df.sort_values("Svs", ascending=False)
#       3 goalie_summary_df.head(15)
#
# NameError: name 'goalie_summary_df' is not defined

# %%
defence_summary_df = pd.read_excel(defence_file, engine="openpyxl")
defence_summary_df.head(10)
# Out:
#            Player    Season Team S/C Pos  GP   G   A   P  +/-  ...  PPG  PPP  \
# 0    Quinn Hughes  20232024  VAN   L   D  39  10  39  49   26  ...    1   17
# 1      Cale Makar  20232024  COL   R   D  35   9  38  47    8  ...    4   21
# 2   Evan Bouchard  20232024  EDM   R   D  36   9  30  39    2  ...    4   19
# 3   Victor Hedman  20232024  TBL   L   D  39   6  33  39   -4  ...    3   17
# 4     Noah Dobson  20232024  NYI   R   D  39   6  32  38   20  ...    1   15
# 5      Vince Dunn  20232024  SEA   L   D  39   7  26  33   -3  ...    3   12
# 6   Rasmus Dahlin  20232024  BUF   L   D  39  12  20  32  -13  ...    3   10
# 7      Roman Josi  20232024  NSH   L   D  40   8  23  31   -1  ...    4   15
# 8   Morgan Rielly  20232024  TOR   L   D  37   4  26  30    2  ...    1   11
# 9  Josh Morrissey  20232024  WPG   L   D  39   6  24  30   21  ...    1    8
#
#    SHG  SHP  OTG  GWG    S    S%  TOI/GP  FOW%
# 0    0    0    1    2   98  10.2   24:34    --
# 1    0    3    0    0  103   8.7   24:34    --
# 2    0    0    0    3  106   8.5   22:42    --
# 3    0    0    0    1   80   7.5   24:27    --
# 4    0    1    0    2   89   6.7   25:53    --
# 5    0    1    0    0   75   9.3   23:20    --
# 6    0    0    0    1  116  10.3   24:57    --
# 7    0    1    1    1  131   6.1   24:29    --
# 8    0    0    0    0   87   4.6   24:32    --
# 9    0    0    0    1  103   5.8   24:18    --
#
# [10 rows x 24 columns]

# %%
defence_icetime_df = defence_summary_df.sort_values("TOI/GP", ascending=False)

defence_icetime_df.head(10)
# Out:
#             Player    Season Team S/C Pos  GP   G   A   P  +/-  ...  PPG  PPP  \
# 32    Drew Doughty  20232024  LAK   R   D  36   7  13  20   11  ...    1    6
# 4      Noah Dobson  20232024  NYI   R   D  39   6  32  38   20  ...    1   15
# 24    John Carlson  20232024  WSH   R   D  38   3  20  23    1  ...    1    9
# 42      Cam Fowler  20232024  ANA   L   D  39   2  16  18  -19  ...    0    8
# 14   Mike Matheson  20232024  MTL   L   D  39   6  21  27   -9  ...    4   15
# 12  Miro Heiskanen  20232024  DAL   L   D  37   4  23  27   -2  ...    1   10
# 6    Rasmus Dahlin  20232024  BUF   L   D  39  12  20  32  -13  ...    3   10
# 37     Brock Faber  20232024  MIN   R   D  38   2  17  19    9  ...    1    4
# 16     Kris Letang  20232024  PIT   R   D  38   3  23  26    9  ...    0    2
# 20  Travis Sanheim  20232024  PHI   L   D  38   4  21  25   -9  ...    0    4
#
#     SHG  SHP  OTG  GWG    S    S%  TOI/GP  FOW%
# 32    0    0    1    3   68  10.3   26:03    --
# 4     0    1    0    2   89   6.7   25:53    --
# 24    0    0    0    1   84   3.6   25:34    --
# 42    0    0    0    0   54   3.7   25:10    --
# 14    0    0    0    0   97   6.2   25:04    --
# 12    0    0    0    1   78   5.1   25:03    --
# 6     0    0    0    1  116  10.3   24:57    --
# 37    0    0    0    1   56   3.6   24:48    --
# 16    0    0    0    0   80   3.8   24:44    --
# 20    0    2    0    2   69   5.8   24:43    --
#
# [10 rows x 24 columns]
